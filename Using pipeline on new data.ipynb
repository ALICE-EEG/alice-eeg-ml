# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import numpy as np
import mne

# %%
from alice_ml.models import predict_mne

# %%
from alice_ml.features import get_features_from_mne

# %%
raw = mne.io.read_raw_fif('alice_ml/data/test_raw.fif', preload=True)
ica = mne.preprocessing.read_ica('alice_ml/data/test_ica.fif')
# Out:
# Opening raw data file alice_ml/data/test_raw.fif...
#     Range : 0 ... 60000 =      0.000 ...   120.000 secs
# Ready.
# Reading 0 ... 60000  =      0.000 ...   120.000 secs...
# Reading alice_ml/data/test_ica.fif ...
# Now restoring ICA solution ...
# Ready.

# %%
features_df = get_features_from_mne(raw, ica)
features_df
# Out:
#                K         MEV       SAD       SVD       SED       MIF  \
# ICA000  0.179616  498.377874  0.015555  0.000003  0.001362  0.027559
# ICA001  1.607034    9.983555  0.694240  0.084712  0.059440  0.051697
# ICA002  0.247652    1.724508  0.078699 -0.013480  0.009139  0.166951
# ICA003  0.053054    2.027428 -0.152254  0.000548  0.074435  0.147758
# ICA004  1.242607    5.039717  0.056761  0.072896  0.509564  0.053082
# ICA005  1.277736    1.733698 -0.108783 -0.019009  0.037082  0.322116
# ICA006  0.022761    1.665512 -0.044637 -0.002575  0.001860  0.136166
# ICA007  0.677950   14.014704 -0.045478  0.000569  0.074319  0.477045
# ICA008  0.130370    1.642786 -0.074464 -0.008309  0.088114  0.178044
# ICA009  0.990489    3.536629 -0.091951 -0.012578  0.002911  0.495697
# ICA010  0.425083    4.513061  0.049869 -0.002584  0.032536  0.305233
# ICA011  0.157997   42.331553  0.024126 -0.000755  0.052578  0.166450
# ICA012  0.024029    1.807874 -0.031467  0.014721  0.034633  0.488916
# ...

# %% [markdown]
# Create predictions

# %%
predict_mne(raw, ica, model='lr', flags= 'all')
# Out:
# /Users/lellight/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:310: UserWarning: Trying to unpickle estimator StandardScaler from version 1.0.1 when using version 0.24.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# /Users/lellight/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:310: UserWarning: Trying to unpickle estimator LogisticRegression from version 1.0.1 when using version 0.24.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# /Users/lellight/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:310: UserWarning: Trying to unpickle estimator LogisticRegression from version 0.24.1 when using version 0.24.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
#         flag_brain  flag_alpha   flag_mu  flag_muscles  flag_eyes  flag_heart  \
# ...

# %%
predict_mne(raw, ica, model='svc', flags=['flag_eyes', 'flag_brain'])
# Out:
# /Users/lellight/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:310: UserWarning: Trying to unpickle estimator StandardScaler from version 1.0.1 when using version 0.24.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# /Users/lellight/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:310: UserWarning: Trying to unpickle estimator SVC from version 1.0.1 when using version 0.24.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
#         flag_eyes  flag_brain
# ICA000   0.117018    0.943840
# ICA001   0.959468    0.000049
# ICA002   0.072020    0.758293
# ICA003   0.068633    0.845542
# ICA004   0.754515    0.000764
# ICA005   0.053985    0.071452
# ICA006   0.080919    0.849680
# ICA007   0.069171    0.052351
# ICA008   0.052858    0.841063
# ICA009   0.050354    0.028466
# ICA010   0.083903    0.239522
# ICA011   0.107580    0.466335
# ICA012   0.081824    0.110428
# ...

# %%
predict_mne(raw, ica, model='xgb', flags= ['flag_eyes', 'flag_brain'])
# Out:
# /Users/lellight/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:310: UserWarning: Trying to unpickle estimator StandardScaler from version 1.0.1 when using version 0.24.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# ---------------------------------------------------------------------------
# XGBoostError                              Traceback (most recent call last)
# /var/folders/5p/07hsl4795y1g6z9hstksgmh00000gn/T/ipykernel_61642/1379253084.py in <module>
# ----> 1 predict_mne(raw, ica, model='xgb')
#
# ~/alice-eeg-ml/alice_ml/models.py in predict_mne(raw, ica, model, flags)
#      29         flags = ['flag_brain', 'flag_alpha', 'flag_mu', 'flag_muscles', 'flag_eyes', 'flag_heart', 'flag_ch_noise']
#      30     for flag in flags:
# ---> 31         models[flag] = joblib.load(pkg_resources.open_binary(pretrained, f'{model}_' + flag + '.joblib'))
#      32
#      33     X = scaler.transform(features_df)
#
# ...
