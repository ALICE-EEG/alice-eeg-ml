# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import numpy as np
import mne

# %%
from alice_ml.models import predict_mne
# Out:
# C:\Users\alsah\anaconda3\lib\site-packages\scipy\__init__.py:138: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.2)
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion} is required for this version of "

# %%
from alice_ml.features import get_features_from_mne

# %%
raw = mne.io.read_raw_fif('alice_ml/data/test_raw.fif', preload=True)
ica = mne.preprocessing.read_ica('alice_ml/data/test_ica.fif')
# Out:
# Opening raw data file alice_ml/data/test_raw.fif...
#     Range : 0 ... 60000 =      0.000 ...   120.000 secs
# Ready.
# Reading 0 ... 60000  =      0.000 ...   120.000 secs...
# Reading alice_ml/data/test_ica.fif ...
# Now restoring ICA solution ...
# Ready.

# %%
features_df = get_features_from_mne(raw, ica)
features_df
# Out:
#                K         MEV       SAD       SVD       SED       MIF  \
# ICA000  0.179616  498.377874  0.015555  0.000003  0.001362  0.027565
# ICA001  1.607034    9.983555  0.694240  0.084712  0.059440  0.051671
# ICA002  0.247652    1.724508  0.078699 -0.013480  0.009139  0.166949
# ICA003  0.053054    2.027428 -0.152254  0.000548  0.074435  0.147775
# ICA004  1.242607    5.039717  0.056761  0.072896  0.509564  0.053076
# ICA005  1.277736    1.733698 -0.108783 -0.019009  0.037082  0.322132
# ICA006  0.022761    1.665512 -0.044637 -0.002575  0.001860  0.136164
# ICA007  0.677950   14.014704 -0.045478  0.000569  0.074319  0.477041
# ICA008  0.130370    1.642786 -0.074464 -0.008309  0.088114  0.178051
# ICA009  0.990489    3.536629 -0.091951 -0.012578  0.002911  0.495702
# ICA010  0.425083    4.513061  0.049869 -0.002584  0.032536  0.305235
# ICA011  0.157997   42.331553  0.024126 -0.000755  0.052578  0.166508
# ICA012  0.024029    1.807874 -0.031467  0.014721  0.034633  0.488910
# ICA013  0.278542    3.883727 -0.045915 -0.000459  0.011900  0.146389
# ICA014  0.372350    6.152992  0.013921  0.001432  0.020229  0.470395
#
#          CORR_BL  CORR_MOVE        AT        MT      AMALB
# ICA000  0.002067   0.003450  0.006224 -0.008901  20.741805
# ICA001  0.015200   0.019600  0.293001 -0.246824   6.175802
# ICA002  0.001583   0.001517  0.141658  0.027020  14.674907
# ICA003  0.000750   0.002083  0.054394  0.093378  13.658469
# ICA004  0.017933   0.018950  0.048418 -0.011424   7.946228
# ICA005  0.000000   0.000000 -0.060637  0.118701  12.260930
# ICA006  0.001167   0.002050 -0.020913  0.096865  16.013635
# ICA007  0.000733   0.001050  0.085639  0.046317   7.302942
# ICA008  0.000633   0.000000 -0.006169  0.046885  15.870912
# ICA009  0.000000   0.000000 -0.052807  0.095031   8.631111
# ICA010  0.001250   0.001417  0.075910 -0.011453  10.365623
# ICA011  0.001300   0.002083 -0.042451  0.002228   6.737137
# ICA012  0.000567   0.001050  0.031184  0.015841   4.389021
# ICA013  0.002117   0.003450 -0.007316  0.037311  15.919984
# ICA014  0.000917   0.001333  0.023835 -0.022695   7.142482

# %% [markdown]
# Create predictions

# %%
predict_mne(raw, ica, model='LR', flags= 'all')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 predict_mne(raw, ica, model='LR', flags= 'all')
#
# File ~\Documents\alice-eeg-ml\alice_ml\models.py:53, in predict_mne(raw, ica, model, features, flags)
#      51 cols = {}
#      52 for flag in flags:
# ---> 53     X = scalers[flag].transform(features_df)
#      54     cols[flag] = models[flag].predict_proba(X[:,ideces[flag]])[:, 1]
#      56 pred_df = pd.DataFrame(cols, index=features_df.index)
#
# File ~\anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:883, in StandardScaler.transform(self, X, copy)
#     880 check_is_fitted(self)
#     882 copy = copy if copy is not None else self.copy
# --> 883 X = self._validate_data(X, reset=False,
#     884                         accept_sparse='csr', copy=copy,
#     885                         estimator=self, dtype=FLOAT_DTYPES,
#     886                         force_all_finite='allow-nan')
#     888 if sparse.issparse(X):
#     889     if self.with_mean:
#
# File ~\anaconda3\lib\site-packages\sklearn\base.py:437, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     434     out = X, y
#     436 if check_params.get('ensure_2d', True):
# --> 437     self._check_n_features(X, reset=reset)
#     439 return out
#
# File ~\anaconda3\lib\site-packages\sklearn\base.py:365, in BaseEstimator._check_n_features(self, X, reset)
#     362     return
#     364 if n_features != self.n_features_in_:
# --> 365     raise ValueError(
#     366         f"X has {n_features} features, but {self.__class__.__name__} "
#     367         f"is expecting {self.n_features_in_} features as input.")
#
# ValueError: X has 11 features, but StandardScaler is expecting 17 features as input.

# %%
predict_mne(raw, ica, model='XGB', flags= ['flag_mu'])
