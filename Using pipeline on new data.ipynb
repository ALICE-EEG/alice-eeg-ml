# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import numpy as np
import mne

# %%
from alice_ml.models import predict_mne
# Out:
# C:\Users\alsah\anaconda3\lib\site-packages\scipy\__init__.py:138: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.2)
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion} is required for this version of "

# %%
from alice_ml.features import get_features_from_mne

# %%
raw = mne.io.read_raw_fif('alice_ml/data/test_raw.fif', preload=True)
ica = mne.preprocessing.read_ica('alice_ml/data/test_ica.fif')
# Out:
# Opening raw data file alice_ml/data/test_raw.fif...
#     Range : 0 ... 60000 =      0.000 ...   120.000 secs
# Ready.
# Reading 0 ... 60000  =      0.000 ...   120.000 secs...
# Reading alice_ml/data/test_ica.fif ...
# Now restoring ICA solution ...
# Ready.

# %%
features_df = get_features_from_mne(raw, ica)
features_df
# Out:
#                K         MEV       SAD       SVD       SED       MIF  \
# ICA000  0.179616  498.377874  0.015555  0.000003  0.001362  0.027565
# ICA001  1.607034    9.983555  0.694240  0.084712  0.059440  0.051671
# ICA002  0.247652    1.724508  0.078699 -0.013480  0.009139  0.166949
# ICA003  0.053054    2.027428 -0.152254  0.000548  0.074435  0.147775
# ICA004  1.242607    5.039717  0.056761  0.072896  0.509564  0.053076
# ICA005  1.277736    1.733698 -0.108783 -0.019009  0.037082  0.322132
# ICA006  0.022761    1.665512 -0.044637 -0.002575  0.001860  0.136164
# ICA007  0.677950   14.014704 -0.045478  0.000569  0.074319  0.477041
# ICA008  0.130370    1.642786 -0.074464 -0.008309  0.088114  0.178051
# ICA009  0.990489    3.536629 -0.091951 -0.012578  0.002911  0.495702
# ICA010  0.425083    4.513061  0.049869 -0.002584  0.032536  0.305235
# ICA011  0.157997   42.331553  0.024126 -0.000755  0.052578  0.166508
# ICA012  0.024029    1.807874 -0.031467  0.014721  0.034633  0.488910
# ICA013  0.278542    3.883727 -0.045915 -0.000459  0.011900  0.146389
# ICA014  0.372350    6.152992  0.013921  0.001432  0.020229  0.470395
#
#          CORR_BL  CORR_MOVE        AT        MT      AMALB   A_peaks  \
# ICA000  0.002067   0.003450  0.006224 -0.008901  20.741805  0.016667
# ICA001  0.015200   0.019600  0.293001 -0.246824   6.175802  0.000000
# ICA002  0.001583   0.001517  0.141658  0.027020  14.674907  0.066667
# ICA003  0.000750   0.002083  0.054394  0.093378  13.658469  0.016667
# ICA004  0.017933   0.018950  0.048418 -0.011424   7.946228  0.000000
# ICA005  0.000000   0.000000 -0.060637  0.118701  12.260930  0.016667
# ICA006  0.001167   0.002050 -0.020913  0.096865  16.013635  0.000000
# ICA007  0.000733   0.001050  0.085639  0.046317   7.302942  0.000000
# ICA008  0.000633   0.000000 -0.006169  0.046885  15.870912  0.100000
# ICA009  0.000000   0.000000 -0.052807  0.095031   8.631111  0.050000
# ICA010  0.001250   0.001417  0.075910 -0.011453  10.365623  0.033333
# ICA011  0.001300   0.002083 -0.042451  0.002228   6.737137  0.016667
# ICA012  0.000567   0.001050  0.031184  0.015841   4.389021  0.000000
# ICA013  0.002117   0.003450 -0.007316  0.037311  15.919984  0.033333
# ICA014  0.000917   0.001333  0.023835 -0.022695   7.142482  0.000000
#
#         A_plateaus  A_peaks_freq  A_plateaus_freq      pca1      pca2
# ICA000    0.066667      8.000000         7.875000  0.140084 -0.937704
# ICA001    0.033333      0.000000         7.000000 -0.036364 -0.003245
# ICA002    0.200000      8.625000         7.875000  0.069591 -0.167731
# ICA003    0.133333      8.500000         8.388889  0.161874  0.049717
# ICA004    0.100000      0.000000         8.416667  0.337671 -0.200216
# ICA005    0.033333      8.000000        10.250000 -0.165503  0.223202
# ICA006    0.233333      0.000000         7.566667 -0.006903  0.164628
# ICA007    0.066667      0.000000         6.875000 -0.085861 -0.204348
# ICA008    0.150000      9.583333         9.111111  0.368459 -0.303650
# ICA009    0.066667     10.833333        10.875000 -0.006253 -0.461690
# ICA010    0.100000      8.250000         7.571429  0.108231 -0.283811
# ICA011    0.066667      8.500000         7.500000  0.197433 -0.344994
# ICA012    0.016667      0.000000         5.500000  0.061713 -0.202014
# ICA013    0.200000      9.500000         7.653846  0.085894 -0.373203
# ICA014    0.000000      0.000000         0.000000  0.041022 -0.166285

# %% [markdown]
# Create predictions

# %%
predict_mne(raw, ica, model='LR', flags= 'all')
# Out:
#          flag_mu  flag_alpha  flag_eyes
# ICA000  0.860324    0.000044   0.864303
# ICA001  0.000002    0.297974   0.972517
# ICA002  0.012425    0.032878   0.115410
# ICA003  0.004332    0.228039   0.099034
# ICA004  0.002000    0.112434   0.970956
# ICA005  0.006308    0.452807   0.120131
# ICA006  0.000261    0.882531   0.080669
# ICA007  0.000526    0.217568   0.229321
# ICA008  0.295140    0.004290   0.148376
# ICA009  0.784154    0.001503   0.163276
# ICA010  0.018287    0.004626   0.191986
# ICA011  0.098755    0.001093   0.245149
# ICA012  0.000216    0.076640   0.157692
# ICA013  0.184079    0.001426   0.176775
# ICA014  0.000018    0.001667   0.182622

# %%
predict_mne(raw, ica, model='XGB', flags= ['flag_mu'])
# Out:
#          flag_mu
# ICA000  0.006573
# ICA001  0.002073
# ICA002  0.003287
# ICA003  0.017415
# ICA004  0.008709
# ICA005  0.009004
# ICA006  0.005751
# ICA007  0.003079
# ICA008  0.012834
# ICA009  0.013737
# ICA010  0.002123
# ICA011  0.004875
# ICA012  0.003266
# ICA013  0.001517
# ICA014  0.002192
